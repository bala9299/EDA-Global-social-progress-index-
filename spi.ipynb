# %% [markdown]
# # Global Social Progress Index
#
# The social progress index (spi) measures the extent to which countries provide for the social and environmental needs of their citizens.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Admin\Desktop\streamlit\spi.csv')
df
# Out:
#      spi_rank                   country  spi_score  basic_human_needs  \
# 0           1                    Norway      92.63              95.29
# 1           2                   Finland      92.26              95.62
# 2           3                   Denmark      92.15              95.30
# 3           4                   Iceland      91.78              96.66
# 4           5               Switzerland      91.78              95.25
# ..        ...                       ...        ...                ...
# 163       164                   Somalia      35.62              40.21
# 164       165                   Eritrea      35.33              44.94
# 165       166                      Chad      34.60              35.65
# 166       167  Central African Republic      33.53              29.91
# 167       168               South Sudan      32.50              39.96
#
#      wellbeing  opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# ...

# %%
df.isnull().sum()
# Out:
# spi_rank                   0
# country                    0
# spi_score                  0
# basic_human_needs          0
# wellbeing                  0
# opportunity                0
# basic_nutri_med_care       0
# water_sanitation           0
# shelter                    0
# personal_safety            0
# access_basic_knowledge     0
# access_info_comm           0
# health_wellness            0
# env_quality                0
# personal_rights            0
# personal_freedom_choice    0
# inclusiveness              0
# access_adv_edu             0
# dtype: int64

# %%
df.describe()
# Out:
#          spi_rank   spi_score  basic_human_needs   wellbeing  opportunity  \
# count  168.000000  168.000000         168.000000  168.000000   168.000000
# mean    84.500000   67.447321          76.154643   67.794345    58.392619
# std     48.641546   15.055894          16.300123   15.441222    15.852476
# min      1.000000   32.500000          29.910000   34.170000    23.370000
# 25%     42.750000   55.055000          62.645000   55.405000    47.797500
# 50%     84.500000   68.265000          82.565000   67.455000    56.345000
# 75%    126.250000   79.145000          88.870000   79.250000    69.795000
# max    168.000000   92.630000          96.850000   93.800000    89.300000
#
#        basic_nutri_med_care  water_sanitation     shelter  personal_safety  \
# count            168.000000        168.000000  168.000000       168.000000
# mean              84.704702         76.159345   77.067083        66.688988
# std               14.457122         23.473682   18.865883        14.441640
# ...

# %% [markdown]
# ### 1.How many countries are there?.
#
# * 168 countries.

# %%
len(df.country)
# Out:
# 168

# %% [markdown]
# ### 2.Which country has a highest spi score?.
#
# * Norway.

# %% [markdown]
# ### 3.List out the top 5 countries which has highest percentage of  basic human needs?.

# %%
df.sort_values(by='basic_human_needs',ascending=False).head()
# Out:
#     spi_rank    country  spi_score  basic_human_needs  wellbeing  opportunity  \
# 8          9      Japan      90.44              96.85      92.93        81.53
# 3          4    Iceland      91.78              96.66      93.65        85.04
# 29        30  Singapore      84.73              96.57      86.87        70.74
# 1          2    Finland      92.26              95.62      93.09        88.07
# 2          3    Denmark      92.15              95.30      92.74        88.41
#
#     basic_nutri_med_care  water_sanitation  shelter  personal_safety  \
# 8                  97.16             97.17    96.87            96.18
# 3                  98.99             98.82    93.16            95.66
# 29                 97.81             95.83    96.48            96.15
# 1                  98.99             99.26    96.48            87.75
# 2                  98.62             98.21    94.92            89.46
#
#     access_basic_knowledge  access_info_comm  health_wellness  env_quality  \
# ...

# %% [markdown]
# ### 4.How many countries have above 90% in basic human needs and well being?.
#
# * 15

# %%
len(df[(df['basic_human_needs']>90) & (df['wellbeing']>90)])
# Out:
# 15

# %% [markdown]
# ###  5.List out the countries of which has lowest % in basic human needs?.

# %%
df.sort_values(by='basic_human_needs',ascending=False).tail()
# Out:
#      spi_rank                        country  spi_score  basic_human_needs  \
# 160       161  Congo. Democratic Republic of      42.11              44.75
# 163       164                        Somalia      35.62              40.21
# 167       168                    South Sudan      32.50              39.96
# 165       166                           Chad      34.60              35.65
# 166       167       Central African Republic      33.53              29.91
#
#      wellbeing  opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 160      48.03        33.53                 60.91             34.97    39.09
# 163      38.41        28.22                 55.75             32.42    35.52
# 167      34.17        23.37                 59.29             24.43    33.28
# 165      36.26        31.87                 47.24             21.48    33.00
# 166      34.83        35.84                 36.42             26.95    26.79
#
# ...

# %% [markdown]
# ### 6.Draw a plot between wellbeing and basic human needs.

# %%
plt.figure(figsize=(18,9))
plt.rcParams.update({'font.size':15})
plt.plot(df['basic_human_needs'],marker='x',c='r',ls='--')
plt.plot(df['wellbeing'],marker='o')
plt.title("percentage between wellbeing and basic human being")
plt.xlabel("spi rank")
plt.ylabel('percentage')
plt.legend(['basic human needs','wellbeing']);

# %% [markdown]
# ### 7.List out the countries which has above 90% and below 50% in oppurtunity.

# %%
#above 85%
df[df['opportunity']>85]
# Out:
#     spi_rank      country  spi_score  basic_human_needs  wellbeing  \
# 0          1       Norway      92.63              95.29      93.30
# 1          2      Finland      92.26              95.62      93.09
# 2          3      Denmark      92.15              95.30      92.74
# 3          4      Iceland      91.78              96.66      93.65
# 4          5  Switzerland      91.78              95.25      93.80
# 5          6       Canada      91.41              94.72      92.83
# 6          7       Sweden      91.20              94.50      91.85
# 7          8  Netherlands      90.57              94.09      91.24
# 9         10      Germany      90.32              94.59      89.35
# 10        11    Australia      90.28              95.12      90.41
#
#     opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 0         89.30                 98.81             98.33    93.75
# 1         88.07                 98.99             99.26    96.48
# ...

# %%
#below 30%
df[df['opportunity']<30]
# Out:
#      spi_rank      country  spi_score  basic_human_needs  wellbeing  \
# 162       163        Yemen      38.90              54.49      38.05
# 163       164      Somalia      35.62              40.21      38.41
# 164       165      Eritrea      35.33              44.94      35.95
# 167       168  South Sudan      32.50              39.96      34.17
#
#      opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 162        24.15                 69.12             41.06    71.73
# 163        28.22                 55.75             32.42    35.52
# 164        25.10                 57.92             27.91    50.27
# 167        23.37                 59.29             24.43    33.28
#
#      personal_safety  access_basic_knowledge  access_info_comm  \
# 162            36.06                   40.59             32.37
# 163            37.17                   25.50             33.40
# 164            43.67                   40.18              6.81
# ...

# %% [markdown]
# ### 8.List out the top 10 spi rank country

# %%
df.country[:10]
# Out:
# 0         Norway
# 1        Finland
# 2        Denmark
# 3        Iceland
# 4    Switzerland
# 5         Canada
# 6         Sweden
# 7    Netherlands
# 8          Japan
# 9        Germany
# Name: country, dtype: object

# %% [markdown]
# ### 9.Which country has a 50th place in opportunity?.
#
# * Burkina Faso.

# %%
df.sort_values(by='opportunity',ascending=True)[50:51]
# Out:
#      spi_rank       country  spi_score  basic_human_needs  wellbeing  \
# 143       144  Burkina Faso      50.65              51.18      51.46
#
#      opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 143        49.31                 64.62             47.07    38.73
#
#      personal_safety  access_basic_knowledge  access_info_comm  \
# 143            54.29                   33.04             60.96
#
#      health_wellness  env_quality  personal_rights  personal_freedom_choice  \
# 143            46.64        65.19             67.9                    43.73
#
#      inclusiveness  access_adv_edu
# 143          49.74           35.87

# %% [markdown]
# ### 10.Draw a plot between basic nutrition medical care and water sanitation.

# %%
plt.figure(figsize=(18,9))
plt.plot(df['basic_nutri_med_care'],marker='x',c='b',ls='--')
plt.plot(df['water_sanitation'],marker='o',c='y')
plt.title("percentage between basic nutrition medical care and water sanitation")
plt.xlabel("spi rank")
plt.ylabel('percentage')
plt.legend([' basic nutrition medical care','water sanitation']);

# %% [markdown]
# ### 11.How many countries have a 90% in shelter and personal safety ?.
#
# * 8 countries.

# %%
len(df[(df['shelter']>90) & (df['personal_safety']>90)])
# Out:
# 8

# %% [markdown]
# ### 12.What is the average personal  safety percentage in world?.
#
# * 66.68%

# %%
df['personal_safety'].mean()
# Out:
# 66.68898809523814

# %% [markdown]
# ### 13.List out the last five countries in basic nutrition medical care.
#
# * Austria.
# * Italy.
# * Sweden.
# * Iceland.
# * Finland.

# %%
df.sort_values(by='basic_nutri_med_care',ascending=True).tail()
# Out:
#     spi_rank  country  spi_score  basic_human_needs  wellbeing  opportunity  \
# 13        14  Austria      89.44              94.42      91.32        82.58
# 22        23    Italy      86.56              91.28      87.77        80.62
# 6          7   Sweden      91.20              94.50      91.85        87.26
# 3          4  Iceland      91.78              96.66      93.65        85.04
# 1          2  Finland      92.26              95.62      93.09        88.07
#
#     basic_nutri_med_care  water_sanitation  shelter  personal_safety  \
# 13                 98.86             98.36    91.21            89.26
# 22                 98.90             97.99    91.79            76.44
# 6                  98.90             98.35    91.80            88.97
# 3                  98.99             98.82    93.16            95.66
# 1                  98.99             99.26    96.48            87.75
#
#     access_basic_knowledge  access_info_comm  health_wellness  env_quality  \
# ...

# %% [markdown]
# ### 14.What are global social progress index of india?.

# %%
df[df["country"]=='India']
# Out:
#      spi_rank country  spi_score  basic_human_needs  wellbeing  opportunity  \
# 114       115   India      58.81              71.32      50.59        54.52
#
#      basic_nutri_med_care  water_sanitation  shelter  personal_safety  \
# 114                 76.04             64.28    82.93            62.04
#
#      access_basic_knowledge  access_info_comm  health_wellness  env_quality  \
# 114                   58.43             59.36            49.45        35.12
#
#      personal_rights  personal_freedom_choice  inclusiveness  access_adv_edu
# 114            69.01                     53.1          43.76           52.22

# %% [markdown]
# ### 15.List out the last five ranking countries.
#
# * South Sudan.
# * Central African Republic.
# * Chad.
# * Eritrea.
# * Somalia.

# %%
df.tail()
# Out:
#      spi_rank                   country  spi_score  basic_human_needs  \
# 163       164                   Somalia      35.62              40.21
# 164       165                   Eritrea      35.33              44.94
# 165       166                      Chad      34.60              35.65
# 166       167  Central African Republic      33.53              29.91
# 167       168               South Sudan      32.50              39.96
#
#      wellbeing  opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 163      38.41        28.22                 55.75             32.42    35.52
# 164      35.95        25.10                 57.92             27.91    50.27
# 165      36.26        31.87                 47.24             21.48    33.00
# 166      34.83        35.84                 36.42             26.95    26.79
# 167      34.17        23.37                 59.29             24.43    33.28
#
#      personal_safety  access_basic_knowledge  access_info_comm  \
# ...

# %% [markdown]
# ### 16.How many countries have below 50% in  personal safety ?.
#
# * 25 countries.

# %%
len(df[df['personal_safety']<50])
# Out:
# 25

# %% [markdown]
# ### 17.What is the least % in personal safety?.
#
# * 29.46% - Central African Republic.

# %%
df.sort_values(by='personal_safety')[:2]
# Out:
#      spi_rank                   country  spi_score  basic_human_needs  \
# 166       167  Central African Republic      33.53              29.91
# 162       163                     Yemen      38.90              54.49
#
#      wellbeing  opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 166      34.83        35.84                 36.42             26.95    26.79
# 162      38.05        24.15                 69.12             41.06    71.73
#
#      personal_safety  access_basic_knowledge  access_info_comm  \
# 166            29.46                   34.81             22.57
# 162            36.06                   40.59             32.37
#
#      health_wellness  env_quality  personal_rights  personal_freedom_choice  \
# 166            24.60        57.35            52.39                    26.67
# 162            40.68        38.56            16.80                    40.64
#
#      inclusiveness  access_adv_edu
# 166          37.87           26.43
# ...

# %% [markdown]
# ### 18. Draw a plot for environmental quality and health wellness.

# %%
plt.figure(figsize=(18,9))
plt.plot(df['env_quality'],marker='o',c='b',ls='--')
plt.plot(df['health_wellness'],marker='x',c='g')
plt.title("percentage between environmental quality and health wellness")
plt.xlabel("spi rank")
plt.ylabel('percentage')
plt.legend(['environmental quality','health wellness']);

# %% [markdown]
# ### 19.What are the countries have above 95% of basic knowledge in accessing and communication?.

# %%
df[(df['access_basic_knowledge']>95) & (df['access_info_comm']>95)]
# Out:
#     spi_rank      country  spi_score  basic_human_needs  wellbeing  \
# 0          1       Norway      92.63              95.29      93.30
# 1          2      Finland      92.26              95.62      93.09
# 2          3      Denmark      92.15              95.30      92.74
# 4          5  Switzerland      91.78              95.25      93.80
# 11        12  New Zealand      90.02              94.30      91.50
# 20        21      Estonia      87.38              92.34      91.10
#
#     opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 0         89.30                 98.81             98.33    93.75
# 1         88.07                 98.99             99.26    96.48
# 2         88.41                 98.62             98.21    94.92
# 4         86.28                 98.72             98.96    92.97
# 11        84.27                 98.04             97.67    89.06
# 20        78.71                 97.56             98.91    94.99
#
# ...

# %% [markdown]
# ### 20.How many countries have above 90% of basic knowledge and 85% of oppurtunity?.
#
# * 10

# %%
len(df[(df['opportunity']>85) & (df['access_basic_knowledge']>90)])
# Out:
# 10

# %% [markdown]
# ### 21.Which countries have below 20% in personal rights?.
#
# * Turkmenistan.
# * Yemen.
# * Eritrea.

# %%
df[df['personal_rights']<20]
# Out:
#      spi_rank       country  spi_score  basic_human_needs  wellbeing  \
# 119       120  Turkmenistan      57.58              82.46      59.74
# 162       163         Yemen      38.90              54.49      38.05
# 164       165       Eritrea      35.33              44.94      35.95
#
#      opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 119        30.52                 91.16             79.32    95.26
# 162        24.15                 69.12             41.06    71.73
# 164        25.10                 57.92             27.91    50.27
#
#      personal_safety  access_basic_knowledge  access_info_comm  \
# 119            64.11                   86.86             41.79
# 162            36.06                   40.59             32.37
# 164            43.67                   40.18              6.81
#
#      health_wellness  env_quality  personal_rights  personal_freedom_choice  \
# 119            51.16        59.18            15.66                    61.62
# ...

# %% [markdown]
# ### 22.Which countries have their citizens with above 90% of personal rights and freedom of their choices?.
#
# * Norway.
# * Denmark.
# * Switzerland.
# * Germany.

# %%
df[(df['personal_rights']>90) & (df['personal_freedom_choice']>90)]
# Out:
#    spi_rank      country  spi_score  basic_human_needs  wellbeing  \
# 0         1       Norway      92.63              95.29      93.30
# 2         3      Denmark      92.15              95.30      92.74
# 4         5  Switzerland      91.78              95.25      93.80
# 9        10      Germany      90.32              94.59      89.35
#
#    opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 0        89.30                 98.81             98.33    93.75
# 2        88.41                 98.62             98.21    94.92
# 4        86.28                 98.72             98.96    92.97
# 9        87.03                 98.70             98.52    91.60
#
#    personal_safety  access_basic_knowledge  access_info_comm  health_wellness  \
# 0            90.29                   98.66             95.80            89.32
# 2            89.46                   97.44             98.18            85.15
# ...

# %% [markdown]
# ### 23.Which countires have above 85% of accessing information and advanced education?.
#
# * Norway.
# * Finland.
# * Australia.
# * Korea.
# * United States.

# %%
df[(df['access_info_comm']>85) & (df['access_adv_edu']>85)]
# Out:
#     spi_rank             country  spi_score  basic_human_needs  wellbeing  \
# 0          1              Norway      92.63              95.29      93.30
# 1          2             Finland      92.26              95.62      93.09
# 10        11           Australia      90.28              95.12      90.41
# 16        17  Korea. Republic of      88.42              95.22      89.66
# 23        24       United States      86.29              89.93      86.67
#
#     opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 0         89.30                 98.81             98.33    93.75
# 1         88.07                 98.99             99.26    96.48
# 10        85.33                 98.34             98.26    91.21
# 16        80.36                 98.18             97.07    93.55
# 23        82.27                 97.51             96.97    92.58
#
#     personal_safety  access_basic_knowledge  access_info_comm  \
# 0             90.29                   98.66             95.80
# ...

# %% [markdown]
# ### 24.Which country have above 90% in medical care, water sanitation, health wellness and environmental quality?.
#
# * Iceland.
# * Switzerland.

# %%
df[(df['basic_nutri_med_care']>90) & (df['water_sanitation']>90) & (df['health_wellness']>90) & (df['env_quality']>90) ]
# Out:
#    spi_rank      country  spi_score  basic_human_needs  wellbeing  \
# 3         4      Iceland      91.78              96.66      93.65
# 4         5  Switzerland      91.78              95.25      93.80
#
#    opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 3        85.04                 98.99             98.82    93.16
# 4        86.28                 98.72             98.96    92.97
#
#    personal_safety  access_basic_knowledge  access_info_comm  health_wellness  \
# 3            95.66                   99.51             93.12            91.02
# 4            90.35                   98.60             95.07            91.50
#
#    env_quality  personal_rights  personal_freedom_choice  inclusiveness  \
# 3        90.93            95.14                    88.01          77.63
# 4        90.05            96.69                    90.65          74.81
#
#    access_adv_edu
# 3           79.39
# 4           82.99

# %% [markdown]
# ### 25.What is the average environmental quality of the world?.
#
# * 67.26%

# %%
df['env_quality'].mean()
# Out:
# 67.26065476190472
